# %%
import chrono_package as cp

# %%
GENE    = 'period'
block   = 2
NN      = 6
address = 'Downloads/gene_{}.csv'.format(GENE)

CP   = cp.CHRONO(address=address, NN=NN, block=block, name=GENE)

DATA = CP.get_measurements()

CP.get_sin_params(DATA[0], DATA[1], limits=[10,100])
# Out:
#  Analyzing period gene...
#
#  Reading the csv file...
#
# Guessed period = 24.0 hrs.
# Fitted period  = 23.0 hrs.
# (array([-2.78511350e-04,  2.73674119e-01,  1.19563953e+00,  4.25727711e-04]),
#  array([1.25119551e-04, 1.32512221e-01, 1.89754513e+00, 1.81730455e-04]))

# %%
CP.plot_curves(DATA, plot_range='smart', which='experimental', title=GENE)
# Out:
#
#  Plot the fitted sine wave...
#
# Guessed period = 24.0 hrs.
# Fitted period  = 24.2 hrs.
#
#
#  Saving the plot in file named period_02.png

# %%
CP.get_measurements?
